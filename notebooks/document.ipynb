# %%
### Data ingestion

# %%
#### document dtata structure

from langchain_core.documents import Document

# %%
doc=Document(
        page_content="this is the main text content I am using to create RAG",
        metadata={
            "source":"exmaple.txt",
            "pages":1,
            "author":"Vansh chapadia",
            "date_created":"2025-02-26"
        }
    )

doc
# Out:
# Document(metadata={'source': 'exmaple.txt', 'pages': 1, 'author': 'Vansh chapadia', 'date_created': '2025-02-26'}, page_content='this is the main text content I am using to create RAG')

# %%
## Create a simple txt file

import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts = {

    "../data/text_files/python_intro.txt": """Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
It was created by Guido van Rossum and first released in 1991. Python's design philosophy emphasizes
code readability and a syntax that allows programmers to express concepts in fewer lines of code compared to other programming languages.

Key features of Python include:
1. Easy to Learn and Use: Python's syntax is clear and straightforward, making it an excellent choice for beginners.
2. Versatility: Python can be used for a wide range of applications, including web development, data analysis, artificial intelligence, scientific computing, and more.
3. Extensive Libraries: Python has a vast ecosystem of libraries and frameworks that extend its functionality, such as NumPy for numerical computing, Pandas for data manipulation, and Django for web development.
4. Cross-Platform: Python is available on various platforms, including Windows, macOS, and Linux.
5. Community Support: Python has a large and active community of developers who contribute to its growth.
""",

    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that focuses on developing algorithms
and statistical models that enable computers to learn from data.

The main types of machine learning include:
1. Supervised Learning
2. Unsupervised Learning
3. Reinforcement Learning

Common machine learning algorithms include:
1. Linear Regression
2. Logistic Regression
3. Decision Trees
4. Support Vector Machines (SVM)
5. Neural Networks
6. K-Nearest Neighbors (KNN)
7. Random Forest
8. Gradient Boosting
9. Clustering Algorithms (K-Means, DBSCAN)
10. Dimensionality Reduction (PCA)
11. Deep Learning
12. Natural Language Processing (NLP)
13. Transfer Learning
14. Ensemble Methods
15. Anomaly Detection
"""
}

for file_path, content in sample_texts.items():
    with open(file_path, "w") as f:
        f.write(content)

print("Sample text files created successfully.")
# Out:
# Sample text files created successfully.

# %%
#### text loader

from langchain.document_loaders import TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")

document=loader.load()

# %%
document
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content="Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nIt was created by Guido van Rossum and first released in 1991. Python's design philosophy emphasizes\ncode readability and a syntax that allows programmers to express concepts in fewer lines of code compared to other programming languages.\n\nKey features of Python include:\n1. Easy to Learn and Use: Python's syntax is clear and straightforward, making it an excellent choice for beginners.\n2. Versatility: Python can be used for a wide range of applications, including web development, data analysis, artificial intelligence, scientific computing, and more.\n3. Extensive Libraries: Python has a vast ecosystem of libraries and frameworks that extend its functionality, such as NumPy for numerical computing, Pandas for data manipulation, and Django for web development.\n4. 
# ...

# %%
 #### directry loader
from langchain.document_loaders import DirectoryLoader

directory_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls= TextLoader ,
    loader_kwargs={"encoding": "utf-8"},
    show_progress=True
    
    )

documents=directory_loader.load()

documents
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 794.53it/s]
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that focuses on developing algorithms\nand statistical models that enable computers to learn from data.\n\nThe main types of machine learning include:\n1. Supervised Learning\n2. Unsupervised Learning\n3. Reinforcement Learning\n\nCommon machine learning algorithms include:\n1. Linear Regression\n2. Logistic Regression\n3. Decision Trees\n4. Support Vector Machines (SVM)\n5. Neural Networks\n6. K-Nearest Neighbors (KNN)\n7. Random Forest\n8. Gradient Boosting\n9. Clustering Algorithms (K-Means, DBSCAN)\n10. Dimensionality Reduction (PCA)\n11. Deep Learning\n12. Natural Language Processing (NLP)\n13. Transfer Learning\n14. Ensemble Methods\n15. Anomaly Detection\n'),
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader

directory_loader=DirectoryLoader(
    "../data/pdf_files",
    glob="**/*.pdf",
    loader_cls= PyPDFLoader ,
    show_progress=True
    
    )



PDF_documents=directory_loader.load()

PDF_documents
